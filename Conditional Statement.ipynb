# %%
from IPython.display import Image              #import image
Image('bill.png')

# %%
amount=0
net_units=float(input('Enter your units'))
if(net_units<=100):
    amount=0
    print ('No charge')
elif (net_units>100 and net_units<=200):   
    amount =(net_units-100)*5
    print ('Amout of units is :',amount)
elif (net_units>200):
    amount=((net_units-200)*10)+500
    print('Amount of units is:',amount)
# Out:
# Enter your units350
# Amount of units is: 2000.0

# %%
from IPython.display import Image
Image('practice.png')

# %%
# practice problem -1
length=float(input('Enter length'))
breadth=float(input('Enter breadth'))
if length==breadth:
    print('It is square')
else:
    print('It is not square')
# Out:
# Enter length4
# Enter breadth3
# It is not square

# %%
# practice problem 1.1
x=float(input('Enter first number'))
y=float(input('Enter second number'))
z=float(input('Enter third number'))

if x<y and z<y :
    print('y is grater',y)
elif y<x and z<x:
    print ('x is grater',x)
elif x<z and y<z:
    print ('z is grater',z)
else:
    print ('they are equal')

# %%
attendance = int(input('Enter your attendance:'))
if (attendance)<75:
    print('Youre not allow for this exam')
else:
    print('you can sit on exam')

# %%
grade = int(input('Enter your grade: '))
if grade<25:
    print('Youre fail')
elif grade>=25 and grade<=44:
    print('You got E')
elif grade>=45 and grade<=49:
    print ('You got D')
elif grade>=50 and grade<=59:
    print('You got C')
elif grade>=60 and grade<=79:
    print('You got B')
elif grade>=80 and grade<=89:
    print ('You got A')
else :
    print ('You got A+')
